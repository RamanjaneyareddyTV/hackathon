# %%
import numpy as np 
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
df_test = pd.read_csv('test_1zqHu22.csv')

# %%
df_test
# Out:
#        row_id  user_id  category_id  video_id  age  gender  \
# 0       89198     7986           12        42   14    Male
# 1       89199    11278           34       115   14    Male
# 2       89200    17245            8       110   44  Female
# 3       89201     9851           16       137   18    Male
# 4       89202    16008           34        96   47  Female
# ...       ...      ...          ...       ...  ...     ...
# 11116  100314    26336           25       140   21    Male
# 11117  100315     6772            8       100   19  Female
# 11118  100316     2042           16        98   22    Male
# 11119  100317    24626            8        16   33    Male
# 11120  100318      967            8        74   33    Male
#
#                  profession  followers  views
# 0                   Student        180    138
# 1                   Student        230    840
# 2      Working Professional        280    628
# 3                   Student        270    462
# ...

# %%
model = open(r'F:\hack\model.pkl','rb')
xgb = pickle.load(model)

# %%
df_test = pd.get_dummies(df_test, columns=[('gender'),('profession')])

# %%
df_test
# Out:
#        row_id  user_id  category_id  video_id  age  followers  views  \
# 0       89198     7986           12        42   14        180    138
# 1       89199    11278           34       115   14        230    840
# 2       89200    17245            8       110   44        280    628
# 3       89201     9851           16       137   18        270    462
# 4       89202    16008           34        96   47        230    840
# ...       ...      ...          ...       ...  ...        ...    ...
# 11116  100314    26336           25       140   21        240    317
# 11117  100315     6772            8       100   19        280    628
# 11118  100316     2042           16        98   22        270    462
# 11119  100317    24626            8        16   33        280    628
# 11120  100318      967            8        74   33        280    628
#
#        gender_Female  gender_Male  profession_Other  profession_Student  \
# ...

# %%
df_result = xgb.predict(df_test)

# %%
df_result
# Out:
# array([4, 4, 3, ..., 3, 3, 3])

# %%
df_test['engagement_score'] = df_result

# %%
df_test.drop(['user_id', 'category_id', 'video_id', 'age', 'followers','views', 'gender_Female', 'gender_Male', 'profession_Other','profession_Student', 'profession_Working Professional',],axis=1, inplace = True)

# %%
df_test.to_csv(r'F:\hack\sample_submisssion.csv', index = False)
