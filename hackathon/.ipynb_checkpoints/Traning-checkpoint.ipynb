# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv('train_0OECtn8.csv')

# %%
df_train.head()
# Out:
#    row_id  user_id  category_id  video_id  age  gender            profession  \
# 0       1    19990           37       128   24    Male               Student
# 1       2     5304           32       132   14  Female               Student
# 2       3     1840           12        24   19    Male               Student
# 3       4    12597           23       112   19    Male               Student
# 4       5    13626           23       112   27    Male  Working Professional
#
#    followers  views  engagement_score
# 0        180   1000              4.33
# 1        330    714              1.79
# 2        180    138              4.35
# 3        220    613              3.77
# 4        220    613              3.13

# %%
df_train.shape
# Out:
# (89197, 10)

# %%
df_train.columns
# Out:
# Index(['row_id', 'user_id', 'category_id', 'video_id', 'age', 'gender',
#        'profession', 'followers', 'views', 'engagement_score'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89197 entries, 0 to 89196
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   row_id            89197 non-null  int64
#  1   user_id           89197 non-null  int64
#  2   category_id       89197 non-null  int64
#  3   video_id          89197 non-null  int64
#  4   age               89197 non-null  int64
#  5   gender            89197 non-null  object
#  6   profession        89197 non-null  object
#  7   followers         89197 non-null  int64
#  8   views             89197 non-null  int64
#  9   engagement_score  89197 non-null  float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 6.8+ MB

# %%
df_train.isnull().sum()
# Out:
# row_id              0
# user_id             0
# category_id         0
# video_id            0
# age                 0
# gender              0
# profession          0
# followers           0
# views               0
# engagement_score    0
# dtype: int64

# %%
df_train = df_train.dropna()

# %%
df_train.describe()
# Out:
#              row_id       user_id   category_id      video_id           age  \
# count  89197.000000  89197.000000  89197.000000  89197.000000  89197.000000
# mean   44599.000000  13881.909806     18.323733     77.715383     24.848616
# std    25749.100318   8005.582771     11.675154     48.469656      8.955535
# min        1.000000      1.000000      1.000000      1.000000     10.000000
# 25%    22300.000000   6945.000000      8.000000     34.000000     18.000000
# 50%    44599.000000  13892.000000     16.000000     76.000000     23.000000
# 75%    66898.000000  20819.000000     26.000000    120.000000     32.000000
# max    89197.000000  27734.000000     47.000000    175.000000     68.000000
#
#           followers         views  engagement_score
# count  89197.000000  89197.000000      89197.000000
# mean     252.460172    502.980268          3.487797
# std       46.094468    268.569482          0.863498
# min      160.000000     30.000000          0.000000
# ...

# %%
df_train.dtypes
# Out:
# row_id                int64
# user_id               int64
# category_id           int64
# video_id              int64
# age                   int64
# gender               object
# profession           object
# followers             int64
# views                 int64
# engagement_score    float64
# dtype: object

# %%
df_train.video_id.value_counts()
# Out:
# 112    1337
# 53     1334
# 1      1282
# 65     1103
# 42     1077
#        ...
# 165      78
# 171      78
# 174      70
# 166      66
# 175      47
# Name: video_id, Length: 175, dtype: int64

# %%
df_train.video_id.unique()
# Out:
# array([128, 132,  24, 112, 139,  14, 100,   4, 161,  88,  75,  72,  48,
#        107, 103,  60,  74,  83,  87,  16, 151,  99,  15, 102, 129, 119,
#         13,  51,  38,  35,  22,  76,  45, 116, 109, 146,   1,  67,  32,
#         53, 148, 140,  63, 115, 108, 113,  92,  33, 117, 114,  50,  17,
#          6, 120,  49,  20, 136,  86,  58, 165,  59,  97,  46,  62, 104,
#         26,  71,  29, 123, 167, 163, 125, 145,  81,  65, 162,  18,  77,
#         36,  25,   9, 124,  98,  31,  94,  10,  95, 156,  68,  23, 135,
#        105, 133, 111,   8,  37,  34,  11, 168,  41, 142, 157, 138, 149,
#         96, 150,  30, 134,  42,  28,  66,  56, 143, 106,  27, 141,  40,
#         82,  64,   7, 174, 101, 121, 126,  12, 158, 144, 131, 147, 137,
#         61, 164,  84, 155, 172, 171,  44, 122,  43,  19,  47, 110,  69,
#        173, 130,   5, 127,  39,  52,  79, 152,   2, 170,  89,  70, 153,
#        160,  91,  93,  90, 154,  80, 159, 169,  54,   3,  55,  21,  78,
# ...

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="gender", data=df_train)

# %%
from matplotlib.pyplot import figure
figure(figsize=(20, 12), dpi=80)
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="age", data=df_train)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="profession", data=df_train)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.displot(x="views", data=df_train)

# %%
import matplotlib.pyplot as plt
df_train.plot(kind='hist',x='gender',y='views',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
df_train.plot(kind='hist',x='profession',y='views',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
df_train.plot(kind='hist',x='age',y='views',color='red')
plt.show()

# %%
df_train = pd.get_dummies(df_train, columns=[('gender'),('profession')])

# %%
df_train.head()
# Out:
#    row_id  user_id  category_id  video_id  age  followers  views  \
# 0       1    19990           37       128   24        180   1000
# 1       2     5304           32       132   14        330    714
# 2       3     1840           12        24   19        180    138
# 3       4    12597           23       112   19        220    613
# 4       5    13626           23       112   27        220    613
#
#    engagement_score  gender_Female  gender_Male  profession_Other  \
# 0              4.33              0            1                 0
# 1              1.79              1            0                 0
# 2              4.35              0            1                 0
# 3              3.77              0            1                 0
# 4              3.13              0            1                 0
#
#    profession_Student  profession_Working Professional
# 0                   1                                0
# 1                   1                                0
# ...

# %%
df_train['engagement_score'] = df_train['engagement_score'].astype(int)

# %%
df_train.head()
# Out:
#    row_id  user_id  category_id  video_id  age  followers  views  \
# 0       1    19990           37       128   24        180   1000
# 1       2     5304           32       132   14        330    714
# 2       3     1840           12        24   19        180    138
# 3       4    12597           23       112   19        220    613
# 4       5    13626           23       112   27        220    613
#
#    engagement_score  gender_Female  gender_Male  profession_Other  \
# 0                 4              0            1                 0
# 1                 1              1            0                 0
# 2                 4              0            1                 0
# 3                 3              0            1                 0
# 4                 3              0            1                 0
#
#    profession_Student  profession_Working Professional
# 0                   1                                0
# 1                   1                                0
# ...

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_train.corr(), yticklabels='auto', annot=True,cmap='YlOrRd')
plt.show()

# %%
sns.pairplot(df_train)

# %%
df_train.columns
# Out:
# Index(['row_id', 'user_id', 'category_id', 'video_id', 'age', 'followers',
#        'views', 'engagement_score', 'gender_Female', 'gender_Male',
#        'profession_Other', 'profession_Student',
#        'profession_Working Professional'],
#       dtype='object')

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df_train['video_id'])
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df_train['age'])
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df_train['views'])
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df_train['engagement_score'])
plt.show()

# %%
x = df_train.drop('engagement_score', axis=1)
y = df_train['engagement_score']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
def predict(algorithm):
    model = algorithm.fit(xtrain,ytrain)
    print('Training Score: {}'.format(model.score(xtrain,ytrain)))

    preds = model.predict(xtest)
    print('Predictions are: {}'.format(preds))
    print('\n')

    r2_score = metrics.r2_score(ytest,preds)
    print('r2_score is:{}'.format(r2_score))

    print('MAE:',metrics.mean_absolute_error(ytest,preds))
    print('MSE:',metrics.mean_squared_error(ytest,preds))
    print('RMSE:',np.sqrt(metrics.mean_squared_error(ytest,preds)))
    sns.distplot(ytest-preds)

# %%
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestRegressor

model_1 = predict(RandomForestRegressor())
# Out:
# Training Score: 0.9006902448462154
# Predictions are: [3.46 3.49 2.76 ... 1.68 2.96 2.27]
#
#
# r2_score is:0.28860000132621433
# MAE: 0.570714125560538
# MSE: 0.5555173654708521
# RMSE: 0.7453303733720048
# C:\Users\Raman\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.linear_model import LinearRegression

model_2 = predict(LinearRegression())
# Out:
# Training Score: 0.2293654547516013
# Predictions are: [3.51904282 3.62323887 3.5006715  ... 2.30703407 2.84471658 2.61333832]
#
#
# r2_score is:0.22871725691518585
# MAE: 0.6071962289923208
# MSE: 0.6022785469080102
# RMSE: 0.7760660712259042
# C:\Users\Raman\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.neighbors import KNeighborsRegressor

model_3 = predict(KNeighborsRegressor())
# Out:
# Training Score: 0.2041050147630129
# Predictions are: [2.4 3.  2.6 ... 2.6 3.4 2.8]
#
#
# r2_score is:-0.18106228997045903
# MAE: 0.7607959641255606
# MSE: 0.9222668161434978
# RMSE: 0.960347237275923
# C:\Users\Raman\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.tree import DecisionTreeRegressor 

model_4 = predict(DecisionTreeRegressor())
# Out:
# Training Score: 1.0
# Predictions are: [4. 4. 4. ... 1. 4. 3.]
#
#
# r2_score is:-0.3448537797173412
# MAE: 0.688060538116592
# MSE: 1.0501681614349776
# RMSE: 1.0247771276892248
# C:\Users\Raman\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import accuracy_score
import xgboost as xgb
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
predictions = [round(value) for value in ypred]
accuracy = accuracy_score(ytest, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# C:\Users\Raman\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:57:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 57.89%

# %%
import pickle

file = open(r'F:\hack\xgb_model.pkl','wb')
